# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaPriya030/-ai-learning-journey/blob/main/Day7_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("="*40)
print("📊 STUDENT MARKS ANALYZER")
print("="*40)
print(f"Average per student : {students.mean(axis=1)}")
print(f"Average per subject : {students.mean(axis=0)}")
print(f"Highest mark        : {students.max()}")
print(f"Lowest mark         : {students.min()}")
print(f"Std deviation       : {students.std():.2f}")
print("="*40)
print(f"Passed : {students[students.mean(axis=1)>=60]}")
print(f"Failed : {students[students.mean(axis=1)<60]}")
print("="*40)
print(f"Train  : {students[:3]}")
print(f"Test   : {students[3:]}")
# Out:
# ...
# 📊 STUDENT MARKS ANALYZER
# ...
# Average per student : [51.66666667 40.         51.66666667 49.         44.33333333]
# Average per subject : [61.6 58.6 21.8]
# Highest mark        : 100
# Lowest mark         : 5
# Std deviation       : 28.57
# ...
# Passed : []
# Failed : [[ 50  80  25]
#  [ 10  50  60]
#  [100  50   5]
#  [ 74  63  10]
#  [ 74  50   9]]
# ...
# Train  : [[ 50  80  25]
#  [ 10  50  60]
#  [100  50   5]]
# Test   : [[74 63 10]
#  [74 50  9]]
